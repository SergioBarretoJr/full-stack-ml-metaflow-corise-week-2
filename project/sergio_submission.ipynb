# %% [markdown]
# # Week 2 Project

# %% [markdown]
# Once again, we’ll be using the [Women's Ecommerce Clothing Reviews Dataset from Kaggle](https://www.kaggle.com/datasets/nicapotato/womens-ecommerce-clothing-reviews), which Kaggle states is a
#
# > dataset revolving around the reviews written by customers. Its nine supportive features offer a great environment to parse out the text through its multiple dimensions. Because this is real commercial data, it has been anonymized, and references to the company in the review text and body have been replaced with “retailer”.
#
# The machine learning task will be sentiment analysis, classifying each review as having positive or negative sentiment.

# %% [markdown]
# ## Task 1: Training and Evaluating Sentiment Analysis Models Using Metaflow
#
# In this task, you'll use Metaflow to build two machine learning models for sentiment analysis: a baseline *"majority class"* classifier and your own custom model. You'll then train both models in parallel and experiment with different hyperparameters to optimize their performance. Finally, you'll use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Here's what you'll need to do:
#
# ### Step 1: Build the Workflows
# The first step in this task is to build the workflow(s) for sentiment analysis using the Metaflow framework. Start by creating a new flow in Metaflow and implementing the baseline *"majority class"* classifier. Then, build your own custom classifier using techniques you learned in Week 1, or any [helpful resources](https://outerbounds.com/docs/nlp-tutorial-L2/) you'd like. For your custom model, be sure to include steps for data preprocessing, model training, and evaluation.
#
# ### Step 2: Train Both Models in Parallel
# Once you've built your models, the next step is to train both models in parallel using the Metaflow framework. Use Metaflow to run both training jobs in parallel steps. If you get stuck, you may want to review the [FlowSpec branching documentation](https://docs.metaflow.org/metaflow/basics#branch).
#
# ### Step 3: Experiment with Hyperparameters
# After you've trained both models in parallel, the next step is to experiment with different hyperparameters to optimize their performance. Try different values for hyperparameters such as learning rate, batch size, and number of epochs, and record the results for each combination of hyperparameters as Data Artifacts in Metaflow.
#
# ### Step 4: Analyze the Results
# Finally, use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Create visualizations to compare the performance of the two models and identify the best hyperparameters for each one.
#
# By completing this task, you'll gain experience working with the Metaflow framework and learn how to build and optimize machine learning workflows for sentiment analysis.

# %%
from collections import Counter
import pandas as pd
import numpy as np 
from termcolor import colored
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
import string

# You can style your plots here, but it is not part of the project.
YELLOW = '#FFBC00'
GREEN = '#37795D'
PURPLE = '#5460C0'
BACKGROUND = '#F4EBE6'
colors = [GREEN, PURPLE]
custom_params = {
    'axes.spines.right': False, 'axes.spines.top': False,
    'axes.facecolor':BACKGROUND, 'figure.facecolor': BACKGROUND, 
    'figure.figsize':(8, 8)
}
sns_palette = sns.color_palette(colors, len(colors))
sns.set_theme(style='ticks', rc=custom_params)

# %%
# TODO: load the data. 
df = pd.read_csv("/home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens Clothing E-Commerce Reviews.csv")
labeling_function = lambda x: 0 if int(x)<=4 else 1
# transformations
df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
df = df[~df.review_text.isna()]
df['review'] = df['review_text'].astype('str')
_has_review_df = df[df['review_text'] != 'nan']
reviews = _has_review_df['review_text']
score = _has_review_df['rating']
labels = score.apply(labeling_function)
df = pd.DataFrame({'label': labels, **_has_review_df})

# split into training and validation.
_df = pd.DataFrame({'review': reviews, 'label': labels})
traindf, valdf = train_test_split(_df, test_size=0.2)

# %%
# TODO: build the majority class baseline model. 
major_class = traindf['label'].mode()[0]
# TODO: find the majority class in the labels. 🤔
base_preds = [major_class] * len(valdf)
# TODO: score the model on valdf with a 2D metric space: sklearn.metrics.accuracy_score, sklearn.metrics.roc_auc_score
# Documentation on suggested model-scoring approach: https://scikit-learn.org/stable/modules/model_evaluation.html
acc = accuracy_score(valdf['label'], base_preds)
auroc = roc_auc_score(valdf['label'], base_preds)

print(acc, auroc)
# Out:
# 0.5511150364318834 0.5

# %%
# %%writefile model.py
# TODO: modify this custom model to your liking. Check out this tutorial for more on this class: https://outerbounds.com/docs/nlp-tutorial-L2/
# TODO: train the model on traindf.
# TODO: score the model on valdf with _the same_ 2D metric space you used in previous cell.
# TODO: test your model works by importing the model module in notebook cells, and trying to fit traindf and score predictions on the valdf data!

import tensorflow as tf
from tensorflow.keras import layers, optimizers, regularizers
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.feature_extraction.text import CountVectorizer

class NbowModel():
    def __init__(self, vocab_sz, l1=1e-5, l2=1e-4, dropout=0.1,learning_rate=0.002, epoch = 10):

        self.vocab_sz = vocab_sz
        self.l1 = l1
        self.l2 = l2
        self.dropout = dropout
        self.learning_rate = learning_rate
        self.epoch = epoch

        # Instantiate the CountVectorizer
        self.cv = CountVectorizer(
            min_df=.005, max_df = .75, stop_words='english', 
            strip_accents='ascii', max_features=self.vocab_sz
        )

        # Define the keras model
        inputs = tf.keras.Input(shape=(self.vocab_sz,), 
                                name='input')
        x = layers.Dropout(self.dropout)(inputs)
        x = layers.Dense(
            15, activation="relu",
            kernel_regularizer=regularizers.L1L2(l1=self.l1, l2=self.l2)
        )(x)
        predictions = layers.Dense(1, activation="sigmoid",)(x)
        self.model = tf.keras.Model(inputs, predictions)
        opt = optimizers.Adam(learning_rate=self.learning_rate)
        self.model.compile(loss="binary_crossentropy", 
                           optimizer=opt, metrics=["accuracy"])

    def fit(self, X, y):
        print(X.shape)
        print(X[0])
        res = self.cv.fit_transform(X).toarray()
        self.model.fit(x=res, y=y, batch_size=32, 
                       epochs=self.epoch, validation_split=.2)
    
    def predict(self, X):
        print(X.shape)
        print(X[0])
        res = self.cv.transform(X).toarray()
        return self.model.predict(res)
    
    def eval_acc(self, X, labels, threshold=.5):
        return accuracy_score(labels, 
                              self.predict(X) > threshold)
    
    def eval_rocauc(self, X, labels):
        return roc_auc_score(labels,  self.predict(X))

    @property
    def model_dict(self): 
        return {'vectorizer':self.cv, 'model': self.model}

    @classmethod
    def from_dict(cls, model_dict):
        "Get Model from dictionary"
        nbow_model = cls(len(
            model_dict['vectorizer'].vocabulary_
        ))
        nbow_model.model = model_dict['model']
        nbow_model.cv = model_dict['vectorizer']
        return nbow_model
# Out:
# Overwriting model.py

# %%
from model import NbowModel

model = NbowModel(vocab_sz=734)

# %%
model.fit(traindf["review"],traindf["label"])
# Out:
# (18112,)
# Absolutely wonderful - silky and sexy and comfortable
# 2023-05-07 21:01:46.860847: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-05-07 21:01:46.878697: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# Epoch 1/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5897 - accuracy: 0.6906 - val_loss: 0.4937 - val_accuracy: 0.7828
# Epoch 2/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4841 - accuracy: 0.7784 - val_loss: 0.4891 - val_accuracy: 0.7822
# Epoch 3/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4623 - accuracy: 0.7923 - val_loss: 0.4915 - val_accuracy: 0.7781
# Epoch 4/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4532 - accuracy: 0.7952 - val_loss: 0.4951 - val_accuracy: 0.7800
# Epoch 5/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4417 - accuracy: 0.8066 - val_loss: 0.4984 - val_accuracy: 0.7828
# Epoch 6/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4305 - accuracy: 0.8154 - val_loss: 0.5077 - val_accuracy: 0.7786
# Epoch 7/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4160 - accuracy: 0.8261 - val_loss: 0.5055 - val_accuracy: 0.7789
# Epoch 8/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4090 - accuracy: 0.8302 - val_loss: 0.5128 - val_accuracy: 0.7833
# Epoch 9/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.3980 - accuracy: 0.8359 - val_loss: 0.5245 - val_accuracy: 0.7784
# Epoch 10/10
# 453/453 [==============================] - 1s 1ms/step - loss: 0.3750 - accuracy: 0.8501 - val_loss: 0.5304 - val_accuracy: 0.7690

# %%
val_acc = model.eval_acc(valdf['review'].values, valdf['label'])
val_auroc = model.eval_rocauc(valdf['review'].values, valdf['label'])
print(val_acc, val_auroc)
# Out:
# (4529,)
# This dress fits well and the material allows for hiding lumps and bumps. material is heavy, yet soft. i could see wearing it with sneakers as the model is, or dressing it up with jewelry and heels. this will be a perfect dress to take on vacation, as it won't get wrinkled and it is so versatile. i'm normally a size 4-8 depending on clothing item, and i bought this in a size small. fits perfect. for reference, i am 38-26-38.
# (4529,)
# This dress fits well and the material allows for hiding lumps and bumps. material is heavy, yet soft. i could see wearing it with sneakers as the model is, or dressing it up with jewelry and heels. this will be a perfect dress to take on vacation, as it won't get wrinkled and it is so versatile. i'm normally a size 4-8 depending on clothing item, and i bought this in a size small. fits perfect. for reference, i am 38-26-38.
# 0.7721351291675866 0.8465448308045455

# %% [markdown]
# Testing hyperparameter tuning

# %%
model = NbowModel(vocab_sz=734,l1=5e-5, l2=5e-4, dropout=0.2,learning_rate=0.01,epoch=20)
model.fit(traindf["review"],traindf["label"])
val_acc = model.eval_acc(valdf['review'].values, valdf['label'])
val_auroc = model.eval_rocauc(valdf['review'].values, valdf['label'])
print(val_acc, val_auroc)
# Out:
# (18112,)
# Absolutely wonderful - silky and sexy and comfortable
# Epoch 1/20
# 453/453 [==============================] - 1s 2ms/step - loss: 0.6169 - accuracy: 0.7179 - val_loss: 0.5839 - val_accuracy: 0.7593
# Epoch 2/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5932 - accuracy: 0.7445 - val_loss: 0.5619 - val_accuracy: 0.7728
# Epoch 3/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5725 - accuracy: 0.7541 - val_loss: 0.5595 - val_accuracy: 0.7698
# Epoch 4/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5647 - accuracy: 0.7578 - val_loss: 0.5578 - val_accuracy: 0.7681
# Epoch 5/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5535 - accuracy: 0.7700 - val_loss: 0.5605 - val_accuracy: 0.7626
# Epoch 6/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5564 - accuracy: 0.7593 - val_loss: 0.5578 - val_accuracy: 0.7676
# Epoch 7/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5494 - accuracy: 0.7680 - val_loss: 0.5610 - val_accuracy: 0.7610
# Epoch 8/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5395 - accuracy: 0.7706 - val_loss: 0.5468 - val_accuracy: 0.7679
# Epoch 9/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7702 - val_loss: 0.5541 - val_accuracy: 0.7659
# Epoch 10/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7666 - val_loss: 0.5472 - val_accuracy: 0.7676
# Epoch 11/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7710 - val_loss: 0.5421 - val_accuracy: 0.7742
# Epoch 12/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7712 - val_loss: 0.5394 - val_accuracy: 0.7717
# Epoch 13/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7679 - val_loss: 0.5479 - val_accuracy: 0.7624
# Epoch 14/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7666 - val_loss: 0.5446 - val_accuracy: 0.7679
# Epoch 15/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5308 - accuracy: 0.7749 - val_loss: 0.5364 - val_accuracy: 0.7698
# Epoch 16/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7704 - val_loss: 0.5452 - val_accuracy: 0.7701
# Epoch 17/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7693 - val_loss: 0.5308 - val_accuracy: 0.7773
# Epoch 18/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5356 - accuracy: 0.7661 - val_loss: 0.5374 - val_accuracy: 0.7684
# Epoch 19/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5307 - accuracy: 0.7685 - val_loss: 0.5341 - val_accuracy: 0.7717
# Epoch 20/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.7665 - val_loss: 0.5407 - val_accuracy: 0.7635
# (4529,)
# This dress fits well and the material allows for hiding lumps and bumps. material is heavy, yet soft. i could see wearing it with sneakers as the model is, or dressing it up with jewelry and heels. this will be a perfect dress to take on vacation, as it won't get wrinkled and it is so versatile. i'm normally a size 4-8 depending on clothing item, and i bought this in a size small. fits perfect. for reference, i am 38-26-38.
# (4529,)
# This dress fits well and the material allows for hiding lumps and bumps. material is heavy, yet soft. i could see wearing it with sneakers as the model is, or dressing it up with jewelry and heels. this will be a perfect dress to take on vacation, as it won't get wrinkled and it is so versatile. i'm normally a size 4-8 depending on clothing item, and i bought this in a size small. fits perfect. for reference, i am 38-26-38.
# 0.7747847206888938 0.8541062650560622

# %%
# %%writefile baseline_challenge.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
import io 
from dataclasses import dataclass

labeling_function = lambda x: 0 if int(x)<=4 else 1

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

class BaselineChallenge(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')

    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        df = pd.read_csv(
            io.StringIO(self.data), 
            index_col=0
        )
        # TODO: load the data. 
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files


        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df['rating'].apply(labeling_function)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        from sklearn.metrics import accuracy_score, roc_auc_score
        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        major_class = self.traindf['label'].mode()[0]
        predictions = [major_class] * len(self.valdf) # TODO: predict the majority class
        acc = accuracy_score(self.valdf['label'], predictions) # TODO: return the accuracy_score of these predictions
        rocauc = roc_auc_score(self.valdf['label'], predictions) # TODO: return the roc_auc_score of these predictions
         
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.next(self.aggregate)

    @step
    def model(self):

        # TODO: import your model if it is defined in another file.
        from model import NbowModel
        
        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100}, {'vocab_sz': 300}, {'vocab_sz': 500}]  
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        for params in self.hyperparam_set:
            model = NbowModel(vocab_sz=734,l1=5e-5, l2=5e-4, dropout=0.2,learning_rate=0.01,epoch=20)
            model.fit(X=self.df['review'], y=self.df['label'])
            acc = model.eval_acc(self.valdf['review'].values, self.valdf['label'])
            rocauc = model.eval_rocauc(self.valdf['review'].values, self.valdf['label'])
            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))

        self.next(self.aggregate)

    @step
    def aggregate(self,inputs):
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge()
# Out:
# Overwriting baseline_challenge.py

# %%
! python baseline_challenge.py run --data '/home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens Clothing E-Commerce Reviews.csv'
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-07 21:04:18.946 Workflow starting (run-id 8), see it in the UI at https://ui-pw-456301247.outerbounds.dev/BaselineChallenge/8
# 2023-05-07 21:04:19.160 [8/start/16 (pid 5016)] Task is starting.
# 2023-05-07 21:04:22.105 [8/start/16 (pid 5016)] num of rows in train set: 18112
# 2023-05-07 21:04:25.192 [8/start/16 (pid 5016)] num of rows in validation set: 4529
# 2023-05-07 21:04:25.448 [8/start/16 (pid 5016)] Task finished successfully.
# 2023-05-07 21:04:25.736 [8/baseline/17 (pid 5128)] Task is starting.
# 2023-05-07 21:04:25.916 [8/model/18 (pid 5131)] Task is starting.
# 2023-05-07 21:04:30.411 [8/model/18 (pid 5131)] 2023-05-07 21:04:30.411367: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-07 21:04:30.654 [8/model/18 (pid 5131)] (22641,)
# 2023-05-07 21:04:30.655 [8/model/18 (pid 5131)] Absolutely wonderful - silky and sexy and comfortable
# 2023-05-07 21
] Epoch 16/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5230 - accuracy: 0.7706 - val_loss: 0.5245 - val_accuracy: 0.7750 - accuracy: 0.87
# 2023-05-07 21:05:12.800 [8/model/18 (pid 5131)] Epoch 17/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7646 - val_loss: 0.5351 - val_accuracy: 0.7633 - accuracy: 0.84
# 2023-05-07 21:05:13.456 [8/model/18 (pid 5131)] Epoch 18/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5295 - accuracy: 0.7684 - val_loss: 0.5253 - val_accuracy: 0.7682 - accuracy: 0.81
# 2023-05-07 21:05:14.126 [8/model/18 (pid 5131)] Epoch 19/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7648 - val_loss: 0.5229 - val_accuracy: 0.7697 - accuracy: 0.90
# 2023-05-07 21:05:14.776 [8/model/18 (pid 5131)] Epoch 20/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5311 - accuracy: 0.7675 - val_loss: 0.5264 - val_accuracy: 0.7719 - accuracy: 0.78
# 2023-05-07 21:05:15.450 [8/model/18 (pid 5131)] (4529,)
# 2023-05-07 21:05:15.706 [8/model/18 (pid 5131)] Bought it on sale and i am keeping it. it is well made an the material seems to be of good quality. however, i believe this would be more flattering on someone less curvy - less hips, smaller bust - as it makes me look slightly pregnant. still, i am keeping it to use on those days i just don't feel like dressing up for work. i bought a large (i'm a 36-38c), but i think i could've gotten away with a medium.
# 2023-05-07 21:05:15.706 [8/model/18 (pid 5131)] (4529,)
# 2023-05-07 21:05:18.666 [8/model/18 (pid 5131)] Bought it on sale and i am keeping it. it is well made an the material seems to be of good quality. however, i believe this would be more flattering on someone less curvy - less hips, smaller bust - as it makes me look slightly pregnant. still, i am keeping it to use on those days i just don't feel like dressing up for work. i bought a large (i'm a 36-38c), but i think i could've gotten away with a medium.
# 2023-05-07 21:05:18.920 [8/model/18 (pid 5131)] Task finished successfully.
# 2023-05-07 21:05:19.395 [8/aggregate/19 (pid 5581)] Task is starting.
# 2023-05-07 21:05:22.098 [8/aggregate/19 (pid 5581)] Task finished successfully.
# 2023-05-07 21:05:22.479 [8/end/20 (pid 5645)] Task is starting.
# 2023-05-07 21:05:24.948 [8/end/20 (pid 5645)] Task finished successfully.
# 2023-05-07 21:05:25.101 Done! See the run in the UI at https://ui-pw-456301247.outerbounds.dev/BaselineChallenge/8

# %% [markdown]
# ## Task 2: Anticipating Failure in Your Machine Learning Project
#
# In this task, you'll practice anticipating potential failure modes in a sentiment analysis classifier and develop strategies to mitigate them. Here's what you'll need to do:
# ### Step 1: Identify Potential Failure Modes
#
# The first step in anticipating failure in your machine learning project is to identify potential failure modes. Start by brainstorming ways in which your project could fail from an engineering point of view. For example, your model could overfit to the training data or suffer from data bias.
# ### Step 2: Develop Strategies to Mitigate Failure Modes
#
# Once you've identified potential failure modes, the next step is to develop strategies to mitigate them. Think about what measures you could take to fix the issue if it were to occur. For example, if your model is overfitting to the training data, you could try regularization techniques such as L1 or L2 regularization to reduce the complexity of the model.
# ### Step 3: Plan Ahead to Avoid Failure Modes
#
# Finally, it's important to plan ahead to avoid potential failure modes in the first place. Think about what you could have done initially to avoid these failure modes. For example, you could have collected a diverse set of training data to reduce data bias or experimented with different model architectures to find the best solution for your problem.
#
# The key to anticipating failure in your machine learning project is to be proactive rather than reactive. By identifying potential failure modes ahead of time and developing strategies to mitigate them, you'll be better equipped to build a successful machine learning project.

# %% [markdown]
# # Answers for Task 2
#
# ## Step 1: Identify Potential Failure Modes
# - Overfitting
# - Poor feature selection
# - Limited training data
# - Limited computational resources
#
# ## Step 2: Develop Strategies to Mitigate Failure Modes
# - Overfitting: If the model overfits to the training data, regularization techniques such as L1 or L2 regularization could be applied to reduce the complexity of the model. Early stopping could also be used to prevent the model from overfitting to the training data.
#
# - Poor feature selection: Feature selection or feature extraction techniques can be used to identify the most relevant features for the problem at hand. If the data is noisy or contains errors, techniques such as outlier detection or imputation can be used to identify and handle the noisy data. In addition, data cleaning and normalization techniques can be applied to ensure that the data is consistent and reliable.
#
# - Limtited training data: If there is insufficient data, one strategy is to use transfer learning, which involves training a model on a large dataset in a related domain and then fine-tuning the model on the smaller dataset
#
# ## Step 3: Plan Ahead to Avoid Failure Modes
# Carefully selecting data sources, collecting data from a variety of demographics, and ensuring that the data is balanced across different classes.
#
# Preprocess data carefully: Proper data preprocessing is critical for machine learning models to perform well.
#
# Experiment with multiple model architectures: Explore deep learning models, ensemble models, and traditional machine learning models.
#
# Regularize your model: Regularization techniques such as L1 or L2 regularization can be used to achieve this.
#
# Validate your model with multiple metrics: It's important to validate your model's performance using multiple metrics

# %% [markdown]
# ## Task 3: Visualizing ML Results with MF Cards
# Now it is time to iterate. Extend the flow in your `baseline_challenge.py` file to include a step that aggregates all of the results from hyperparameter tuning jobs, and logs results and a data visualiation in a Metaflow card.

# %%
# %%writefile baseline_challenge.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
import io 
from dataclasses import dataclass

labeling_function = lambda x: 0 if int(x)<=4 else 1

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

class BaselineChallenge(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')

    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        df = pd.read_csv(
            io.StringIO(self.data), 
            index_col=0
        )
        # TODO: load the data. 
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files


        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df['rating'].apply(labeling_function)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        from sklearn.metrics import accuracy_score, roc_auc_score
        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        major_class = self.traindf['label'].mode()[0]
        predictions = [major_class] * len(self.valdf) # TODO: predict the majority class
        acc = accuracy_score(self.valdf['label'], predictions) # TODO: return the accuracy_score of these predictions
        rocauc = roc_auc_score(self.valdf['label'], predictions) # TODO: return the roc_auc_score of these predictions
         
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.next(self.aggregate)

    @step
    def model(self):

        # TODO: import your model if it is defined in another file.
        from model import NbowModel
        
        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100}, {'vocab_sz': 300}, {'vocab_sz': 500}]  
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        for params in self.hyperparam_set:
            model = NbowModel(vocab_sz=734,l1=5e-5, l2=5e-4, dropout=0.2,learning_rate=0.01,epoch=20)
            model.fit(X=self.df['review'], y=self.df['label'])
            acc = model.eval_acc(self.valdf['review'].values, self.valdf['label'])
            rocauc = model.eval_rocauc(self.valdf['review'].values, self.valdf['label'])
            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))

        self.next(self.aggregate)

    def add_one(self, rows, result, df):
        "A helper function to load results."
        rows.append([
            Markdown(result.name),
            Artifact(result.params),
            Artifact(result.pathspec),
            Artifact(result.acc),
            Artifact(result.rocauc)
        ])
        df['name'].append(result.name)
        df['accuracy'].append(result.acc)
        return rows, df

    @card(type='corise')  # TODO: Set your card type to "corise". 
            # I wonder what other card types there are?
            # https://docs.metaflow.org/metaflow/visualizing-results
            # https://github.com/outerbounds/metaflow-card-altair/blob/main/altairflow.py
    @step
    def aggregate(self, inputs):

        import seaborn as sns
        import matplotlib.pyplot as plt
        from matplotlib import rcParams 
        rcParams.update({'figure.autolayout': True})

        rows = []
        violin_plot_df = {'name': [], 'accuracy': []}
        for task in inputs:
            if task._name == "model": 
                for result in task.results:
                    print(result)
                    rows, violin_plot_df = self.add_one(rows, result, violin_plot_df)
            elif task._name == "baseline":
                print(task.result)
                rows, violin_plot_df = self.add_one(rows, task.result, violin_plot_df)
            else:
                raise ValueError("Unknown task._name type. Cannot parse results.")
            
        current.card.append(Markdown("# All models from this flow run"))

        # TODO: Add a Table of the results to your card! 
        current.card.append(
            Table(
                rows, # TODO: What goes here to populate the Table in the card? 
                headers=["Model name", "Params", "Task pathspec", "Accuracy", "ROCAUC"]
            )
        )
        
        fig, ax = plt.subplots(1,1)
        plt.xticks(rotation=40)
        sns.violinplot(data=violin_plot_df, x="name", y="accuracy", ax=ax)
        
        # TODO: Append the matplotlib fig to the card
        # Docs: https://docs.metaflow.org/metaflow/visualizing-results/easy-custom-reports-with-card-components#showing-plots
        current.card.append(Image.from_matplotlib(fig))
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge()
# Out:
# Overwriting baseline_challenge.py

# %%
! python baseline_challenge.py run --data '/home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens Clothing E-Commerce Reviews.csv'
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file /home/workspace/workspaces/full-stack-ml-metaflow-corise-week-2/data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-07 21:08:19.859 Workflow starting (run-id 9), see it in the UI at https://ui-pw-456301247.outerbounds.dev/BaselineChallenge/9
# 2023-05-07 21:08:20.094 [9/start/22 (pid 5834)] Task is starting.
# 2023-05-07 21:08:23.026 [9/start/22 (pid 5834)] num of rows in train set: 18112
# 2023-05-07 21:08:25.702 [9/start/22 (pid 5834)] num of rows in validation set: 4529
# 2023-05-07 21:08:25.934 [9/start/22 (pid 5834)] Task finished successfully.
# 2023-05-07 21:08:26.225 [9/baseline/23 (pid 5949)] Task is starting.
# 2023-05-07 21:08:26.456 [9/model/24 (pid 5952)] Task is starting.
# 2023-05-07 21:08:30.786 [9/model/24 (pid 5952)] 2023-05-07 21:08:30.785985: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-07 21:08:31.079 [9/model/24 (pid 5952)] (22641,)
# 2023-05-07 21:08:31.079 [9/model/24 (pid 5952)] Absolutely wonderful - silky and sexy and comfortable
# 2023-05-07 21:08:31.830 [9/baseline/23 (pid 5949)] Task finished successfully.
# 2023-05-07 21:08:32.096 [9/model/24 (pid 5952)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-07 21:08:32.096 [9/model/24 (pid 5952)] 2023-05-07 21:08:32.096626: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-05-07 21:08:32.114 [9/model/24 (pid 5952)] 2023-05-07 21:08:32.114669: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# 2023-05-07 21:08:32.123 [9/model/24 (pid 5952)] Epoch 1/20
# 566/566 [==============================] - 1s 2ms/step - loss: 0.6170 - accuracy: 0.7140 - val_loss: 0.5719 - val_accuracy: 0.757174 - accuracy: 0.62
# 2023-05-07 21:08:33.568 [9/model/24 (pid 5952)] Epoch 2/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5732 - accuracy: 0.7520 - val_loss: 0.5559 - val_accuracy: 0.7646 - accuracy: 0.75
# 2023-05-07 21:08:34.303 [9/model/24 (pid 5952)] Epoch 3/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5671 - accuracy: 0.7559 - val_loss: 0.5590 - val_accuracy: 0.7554 - accuracy: 0.81
# 2023-05-07 21:08:34.953 [9/model/24 (pid 5952)] Epoch 4/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5546 - accuracy: 0.7636 - val_loss: 0.5496 - val_accuracy: 0.7640 - accuracy: 0.84
# 2023-05-07 21:08:35.609 [9/model/24 (pid 5952)] Epoch 5/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5461 - accuracy: 0.7655 - val_loss: 0.5391 - val_accuracy: 0.7697 - accuracy: 0.75
# 2023-05-07 21:08:36.260 [9/model/24 (pid 5952)] Epoch 6/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7643 - val_loss: 0.5367 - val_accuracy: 0.7637 - accuracy: 0.78
# 2023-05-07 21:08:36.915 [9/model/24 (pid 5952)] Epoch 7/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7624 - val_loss: 0.5404 - val_accuracy: 0.7671 - accuracy: 0.68
# 2023-05-07 21:08:37.562 [9/model/24 (pid 5952)] Epoch 8/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5352 - accuracy: 0.7635 - val_loss: 0.5340 - val_accuracy: 0.7666 - accuracy: 0.71
# 2023-05-07 21:08:38.190 [9/model/24 (pid 5952)] Epoch 9/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7606 - val_loss: 0.5256 - val_accuracy: 0.7706 - accuracy: 0.75
# 2023-05-07 21:08:38.855 [9/model/24 (pid 5952)] Epoch 10/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.7688 - val_loss: 0.5257 - val_accuracy: 0.7710 - accuracy: 0.90
# 2023-05-07 21:08:39.480 [9/model/24 (pid 5952)] Epoch 11/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5283 - accuracy: 0.7688 - val_loss: 0.5321 - val_accuracy: 0.7675 - accuracy: 0.68
# 2023-05-07 21:08:40.109 [9/model/24 (pid 5952)] Epoch 12/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7652 - val_loss: 0.5351 - val_accuracy: 0.7582 - accuracy: 0.81
# 2023-05-07 21:08:40.748 [9/model/24 (pid 5952)] Epoch 13/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7583 - val_loss: 0.5317 - val_accuracy: 0.7728 - accuracy: 0.71
# 2023-05-07 21:08:41.389 [9/model/24 (pid 5952)] Epoch 14/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.
20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5245 - accuracy: 0.7669 - val_loss: 0.5249 - val_accuracy: 0.7693 - accuracy: 0.75
# 2023-05-07 21:09:10.445 [9/model/24 (pid 5952)] Epoch 13/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5377 - accuracy: 0.7570 - val_loss: 0.5299 - val_accuracy: 0.7624 - accuracy: 0.78
# 2023-05-07 21:09:11.077 [9/model/24 (pid 5952)] Epoch 14/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7621 - val_loss: 0.5221 - val_accuracy: 0.7701 - accuracy: 0.78
# 2023-05-07 21:09:11.727 [9/model/24 (pid 5952)] Epoch 15/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7638 - val_loss: 0.5273 - val_accuracy: 0.7653 - accuracy: 0.87
# 2023-05-07 21:09:12.365 [9/model/24 (pid 5952)] Epoch 16/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5305 - accuracy: 0.7627 - val_loss: 0.5249 - val_accuracy: 0.7715 - accuracy: 0.84
# 2023-05-07 21:09:12.997 [9/model/24 (pid 5952)] Epoch 17/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5291 - accuracy: 0.7671 - val_loss: 0.5214 - val_accuracy: 0.7695 - accuracy: 0.78
# 2023-05-07 21:09:13.650 [9/model/24 (pid 5952)] Epoch 18/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7653 - val_loss: 0.5325 - val_accuracy: 0.7607 - accuracy: 0.81
# 2023-05-07 21:09:14.286 [9/model/24 (pid 5952)] Epoch 19/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7625 - val_loss: 0.5230 - val_accuracy: 0.7717 - accuracy: 0.78
# 2023-05-07 21:09:14.930 [9/model/24 (pid 5952)] Epoch 20/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.5298 - accuracy: 0.7672 - val_loss: 0.5270 - val_accuracy: 0.7713 - accuracy: 0.75
# 2023-05-07 21:09:15.588 [9/model/24 (pid 5952)] (4529,)
# 2023-05-07 21:09:15.879 [9/model/24 (pid 5952)] I discovered this top folded on a shelf and loved the material and this brand so i decided to try it on... even though it's super hot right now in ar. i'm so glad i did and ended up finding the other color and buying both. i am 5'9", 127#, 34b and long waisted. it is difficult to tell in the pictures how this top fits around the waist... it is snug fitting but the material is thicker so i feel like it's very flattering. i tried it on as a boat neck look, then saw online it was off the shoulder a
# 2023-05-07 21:09:15.879 [9/model/24 (pid 5952)] (4529,)
# 2023-05-07 21:09:18.750 [9/model/24 (pid 5952)] I discovered this top folded on a shelf and loved the material and this brand so i decided to try it on... even though it's super hot right now in ar. i'm so glad i did and ended up finding the other color and buying both. i am 5'9", 127#, 34b and long waisted. it is difficult to tell in the pictures how this top fits around the waist... it is snug fitting but the material is thicker so i feel like it's very flattering. i tried it on as a boat neck look, then saw online it was off the shoulder a
# 2023-05-07 21:09:18.960 [9/model/24 (pid 5952)] Task finished successfully.
# 2023-05-07 21:09:19.378 [9/aggregate/25 (pid 6357)] Task is starting.
# 2023-05-07 21:09:22.531 [9/aggregate/25 (pid 6357)] ModelResult(name='Baseline', params='Always predict 1', pathspec='BaselineChallenge/9/baseline/23', acc=0.559284610289247, rocauc=0.5)
# 2023-05-07 21:09:22.576 [9/aggregate/25 (pid 6357)] ModelResult(name='NbowModel - vocab_sz: 100', params={'vocab_sz': 100}, pathspec='BaselineChallenge/9/model/24', acc=0.7882534775888718, rocauc=0.859437489269894)
# 2023-05-07 21:09:22.576 [9/aggregate/25 (pid 6357)] ModelResult(name='NbowModel - vocab_sz: 300', params={'vocab_sz': 300}, pathspec='BaselineChallenge/9/model/24', acc=0.7856038860675646, rocauc=0.8562300281573807)
# 2023-05-07 21:09:25.473 [9/aggregate/25 (pid 6357)] ModelResult(name='NbowModel - vocab_sz: 500', params={'vocab_sz': 500}, pathspec='BaselineChallenge/9/model/24', acc=0.7811879001987193, rocauc=0.8582870438864305)
# 2023-05-07 21:09:25.682 [9/aggregate/25 (pid 6357)] Task finished successfully.
# 2023-05-07 21:09:26.023 [9/end/26 (pid 6453)] Task is starting.
# 2023-05-07 21:09:28.590 [9/end/26 (pid 6453)] Task finished successfully.
# 2023-05-07 21:09:28.722 Done! See the run in the UI at https://ui-pw-456301247.outerbounds.dev/BaselineChallenge/9
